# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
height=[[1.6],[1.65],[1.8],[1.7],[1.56],[1.62],[1.63],[1.62],[1.83],[1.72],[1.70],[1.62],[1.71],[1.65],[1.78],[1.79],[1.6],[1.62],[1.61],[1.68],[1.83],[1.72],[1.75],[1.66],[1.65],[1.7],[1.68],[1.74],[1.57],[1.8]]
weight=[[60],[65],[80],[72],[75],[70],[62],[65],[80],[77],[74],[72],[70],[65],[80],[72],[75],[70],[65],[65],[85],[77],[80],[78],[62],[70],[64],[80],[74],[88]]
model=LinearRegression()
model.fit(X=height,y=weight)
w=model.predict([[1.75]])
print(w)
import matplotlib.pyplot as plt
plt.xlabel('heights is meter for peaple')
plt.ylabel('weights is kilogram for peaple')
plt.plot(height,weight)
plt.grid(True)
plt.show()
# Out:
# [[76.56277005]]
